# %%
import pandas as pd

# %%
match=pd.read_excel("Match.xlsx")

# %%
match.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Match_Id             577 non-null    int64
#  1   Match_Date           577 non-null    datetime64[ns]
#  2   Team_Name_Id         577 non-null    int64
#  3   Opponent_Team_Id     577 non-null    int64
#  4   Season_Id            577 non-null    int64
#  5   Venue_Name           577 non-null    object
#  6   Toss_Winner_Id       577 non-null    int64
#  7   Toss_Decision        577 non-null    object
#  8   IS_Superover         577 non-null    int64
#  9   IS_Result            577 non-null    int64
#  10  Is_DuckWorthLewis    577 non-null    int64
#  11  Win_Type             577 non-null    object
#  12  Won_By               568 non-null    float64
#  13  Match_Winner_Id      574 non-null    float64
#  14  Man_Of_The_Match_Id  574 non-null    float64
# ...

# %%
print("No of season ",match['Season_Id'].nunique())
# Out:
# No of season  9

# %%
len(match[match['Season_Id']==1])
# Out:
# 58

# %%
len(match[match['Match_Winner_Id']==3.0][match['Win_Type']=='by wickets'])
# Out:
# C:\Users\NAGEND~1\AppData\Local\Temp/ipykernel_33984/760392876.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(match[match['Match_Winner_Id']==3.0][match['Win_Type']=='by wickets'])
# 33

# %%
match[match['Season_Id']==1]['Match_Id'].count()
# Out:
# 58

# %%
matchcount =match['Season_Id'].value_counts()

# %%
matchcount.sort_values()
# Out:
# 2    57
# 1    58
# 8    59
# 3    60
# 7    60
# 9    60
# 4    73
# 5    74
# 6    76
# Name: Season_Id, dtype: int64

# %%
matchcount=matchcount.sort_index()

# %%
matchcount=matchcount.reset_index()

# %%
matchcount.columns=["SeasonID","match count"]

# %%
matchcount.sort_values(by="match count",ascending=False)
# Out:
#    SeasonID  match count
# 5         6           76
# 4         5           74
# 3         4           73
# 2         3           60
# 6         7           60
# 8         9           60
# 7         8           59
# 0         1           58
# 1         2           57

# %%
winner_of_S1=match[match["Season_Id"]==1]["Match_Winner_Id"].value_counts().reset_index()

# %%
winner_of_S1.columns=["Match_Winner_Id","count"]

# %%
winner_of_S1
# Out:
#    Match_Winner_Id  count
# 0              5.0     13
# 1              4.0     10
# 2              3.0      9
# 3              7.0      7
# 4              6.0      7
# 5              1.0      6
# 6              2.0      4
# 7              8.0      2

# %%
team=pd.read_excel("Team.xlsx")

# %%
team
# Out:
#     Team_Id                    Team_Name Team_Short_Code
# 0         1        Kolkata Knight Riders             KKR
# 1         2  Royal Challengers Bangalore             RCB
# 2         3          Chennai Super Kings             CSK
# 3         4              Kings XI Punjab            KXIP
# 4         5             Rajasthan Royals              RR
# 5         6             Delhi Daredevils              DD
# 6         7               Mumbai Indians              MI
# 7         8              Deccan Chargers              DC
# 8         9         Kochi Tuskers Kerala             KTK
# 9        10                Pune Warriors              PW
# 10       11          Sunrisers Hyderabad             SRH
# 11       12      Rising Pune Supergiants             RPS
# 12       13                Gujarat Lions              GL

# %%
pd.merge(winner_of_S1,team,how="inner",left_on="Match_Winner_Id",right_on="Team_Id")
# Out:
#    Match_Winner_Id  count  Team_Id                    Team_Name  \
# 0              5.0     13        5             Rajasthan Royals
# 1              4.0     10        4              Kings XI Punjab
# 2              3.0      9        3          Chennai Super Kings
# 3              7.0      7        7               Mumbai Indians
# 4              6.0      7        6             Delhi Daredevils
# 5              1.0      6        1        Kolkata Knight Riders
# 6              2.0      4        2  Royal Challengers Bangalore
# 7              8.0      2        8              Deccan Chargers
#
#   Team_Short_Code
# 0              RR
# 1            KXIP
# 2             CSK
# 3              MI
# 4              DD
# 5             KKR
# 6             RCB
# 7              DC

# %%
pd.merge(winner_of_S1,team,how="inner",left_on="Match_Winner_Id",right_on="Team_Id")[["Team_Id","Team_Name","count"]]
# Out:
#    Team_Id                    Team_Name  count
# 0        5             Rajasthan Royals     13
# 1        4              Kings XI Punjab     10
# 2        3          Chennai Super Kings      9
# 3        7               Mumbai Indians      7
# 4        6             Delhi Daredevils      7
# 5        1        Kolkata Knight Riders      6
# 6        2  Royal Challengers Bangalore      4
# 7        8              Deccan Chargers      2

# %%
pd.merge(team,winner_of_S1,how="inner",left_on="Team_Id",right_on="Match_Winner_Id")
# Out:
#    Team_Id                    Team_Name Team_Short_Code  Match_Winner_Id  \
# 0        1        Kolkata Knight Riders             KKR              1.0
# 1        2  Royal Challengers Bangalore             RCB              2.0
# 2        3          Chennai Super Kings             CSK              3.0
# 3        4              Kings XI Punjab            KXIP              4.0
# 4        5             Rajasthan Royals              RR              5.0
# 5        6             Delhi Daredevils              DD              6.0
# 6        7               Mumbai Indians              MI              7.0
# 7        8              Deccan Chargers              DC              8.0
#
#    count
# 0      6
# 1      4
# 2      9
# 3     10
# 4     13
# 5      7
# 6      7
# 7      2

# %%
pd.merge(team,winner_of_S1,how="left",left_on="Team_Id",right_on="Match_Winner_Id")
# Out:
#     Team_Id                    Team_Name Team_Short_Code  Match_Winner_Id  \
# 0         1        Kolkata Knight Riders             KKR              1.0
# 1         2  Royal Challengers Bangalore             RCB              2.0
# 2         3          Chennai Super Kings             CSK              3.0
# 3         4              Kings XI Punjab            KXIP              4.0
# 4         5             Rajasthan Royals              RR              5.0
# 5         6             Delhi Daredevils              DD              6.0
# 6         7               Mumbai Indians              MI              7.0
# 7         8              Deccan Chargers              DC              8.0
# 8         9         Kochi Tuskers Kerala             KTK              NaN
# 9        10                Pune Warriors              PW              NaN
# 10       11          Sunrisers Hyderabad             SRH              NaN
# 11       12      Rising Pune Supergiants             RPS              NaN
# ...

# %%
pd.merge(winner_of_S1,team,how="right",left_on="Match_Winner_Id",right_on="Team_Id")
# Out:
#     Match_Winner_Id  count  Team_Id                    Team_Name  \
# 0               1.0    6.0        1        Kolkata Knight Riders
# 1               2.0    4.0        2  Royal Challengers Bangalore
# 2               3.0    9.0        3          Chennai Super Kings
# 3               4.0   10.0        4              Kings XI Punjab
# 4               5.0   13.0        5             Rajasthan Royals
# 5               6.0    7.0        6             Delhi Daredevils
# 6               7.0    7.0        7               Mumbai Indians
# 7               8.0    2.0        8              Deccan Chargers
# 8               NaN    NaN        9         Kochi Tuskers Kerala
# 9               NaN    NaN       10                Pune Warriors
# 10              NaN    NaN       11          Sunrisers Hyderabad
# 11              NaN    NaN       12      Rising Pune Supergiants
# 12              NaN    NaN       13                Gujarat Lions
#
#    Team_Short_Code
# 0              KKR
# ...

# %%
pd.merge(winner_of_S1,team,how="outer",left_on="Match_Winner_Id",right_on="Team_Id")
# Out:
#     Match_Winner_Id  count  Team_Id                    Team_Name  \
# 0               5.0   13.0        5             Rajasthan Royals
# 1               4.0   10.0        4              Kings XI Punjab
# 2               3.0    9.0        3          Chennai Super Kings
# 3               7.0    7.0        7               Mumbai Indians
# 4               6.0    7.0        6             Delhi Daredevils
# 5               1.0    6.0        1        Kolkata Knight Riders
# 6               2.0    4.0        2  Royal Challengers Bangalore
# 7               8.0    2.0        8              Deccan Chargers
# 8               NaN    NaN        9         Kochi Tuskers Kerala
# 9               NaN    NaN       10                Pune Warriors
# 10              NaN    NaN       11          Sunrisers Hyderabad
# 11              NaN    NaN       12      Rising Pune Supergiants
# 12              NaN    NaN       13                Gujarat Lions
#
#    Team_Short_Code
# 0               RR
# ...

# %%
match["Match_Winner_Id"]==3
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# Name: Match_Winner_Id, Length: 577, dtype: bool

# %%
match[match['Win_Type']=="by wickets"]
# Out:
#      Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 2      335989 2008-04-19             6                 5          1
# 3      335990 2008-04-20             7                 2          1
# 4      335991 2008-04-20             1                 8          1
# 5      335992 2008-04-21             5                 4          1
# 6      335993 2008-04-22             8                 6          1
# ..        ...        ...           ...               ...        ...
# 569    981010 2016-05-21            12                 4          9
# 570    981012 2016-05-21            13                 7          9
# 572    981016 2016-05-22             6                 2          9
# 573    981018 2016-05-24            13                 2          9
# 575    981022 2016-05-27            13                11          9
#
#                                             Venue_Name  Toss_Winner_Id  \
# 2                                     Feroz Shah Kotla               5
# ...

# %%
len(match[match["Match_Winner_Id"]==3.0][match['Win_Type']=="by wickets"])
# Out:
# 307

# %%
# len(match[match["Match_Winner_Id"]==3.0][match['Win_Type']=="by wickets"])

# %%
match_team=pd.merge(match,team,how="inner",left_on="Match_Winner_Id",right_on="Team_Id")

# %%
match.head(1)
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987 2008-04-18             2                 1          1
#
#               Venue_Name  Toss_Winner_Id Toss_Decision  IS_Superover  \
# 0  M Chinnaswamy Stadium               2         field             0
#
#    IS_Result  Is_DuckWorthLewis Win_Type  Won_By  Match_Winner_Id  \
# 0          1                  0  by runs   140.0              1.0
#
#    Man_Of_The_Match_Id  First_Umpire_Id  Second_Umpire_Id  City_Name  \
# 0                  2.0              470               477  Bangalore
#
#   Host_Country
# 0        India

# %%
len(match_team[match_team['Team_Short_Code']=="CSK"][match_team['Win_Type']=='by wickets'])
# Out:
# C:\Users\NAGEND~1\AppData\Local\Temp/ipykernel_33984/4115684304.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(match_team[match_team['Team_Short_Code']=="CSK"][match_team['Win_Type']=='by wickets'])
# 33

# %%
total_wins=match["Match_Winner_Id"].value_counts().sort_values()
total_wins
# Out:
# 12.0     5
# 9.0      6
# 13.0     9
# 10.0    12
# 8.0     29
# 11.0    34
# 6.0     56
# 5.0     63
# 4.0     63
# 1.0     68
# 2.0     70
# 3.0     79
# 7.0     80
# Name: Match_Winner_Id, dtype: int64

# %%
match.groupby("Team_Name_Id")["Match_Winner_Id"].value_counts()
# Out:
# Team_Name_Id  Match_Winner_Id
# 1             1.0                37
#               7.0                 7
#               3.0                 4
#               2.0                 3
#               4.0                 3
#                                  ..
# 13            13.0                4
#               11.0                2
#               2.0                 1
#               4.0                 1
#               6.0                 1
# Name: Match_Winner_Id, Length: 118, dtype: int64

# %%
home_match=match["Team_Name_Id"].value_counts().sort_index()

# %%
opposite_team=match["Opponent_Team_Id"].value_counts().sort_index()

# %%
opposite_team
# Out:
# 1     70
# 2     61
# 3     57
# 4     69
# 5     66
# 6     64
# 7     78
# 8     36
# 9      7
# 10    23
# 11    32
# 12     7
# 13     7
# Name: Opponent_Team_Id, dtype: int64

# %%
total_match=home_match+opposite_team

# %%
total_match
# Out:
# 1     132
# 2     139
# 3     131
# 4     134
# 5     118
# 6     133
# 7     140
# 8      75
# 9      14
# 10     46
# 11     62
# 12     14
# 13     16
# dtype: int64

# %%
win_percent=((total_wins*100)/total_match).reset_index()

# %%
win_percent.columns
# Out:
#     index          0
# 0     1.0  51.515152
# 1     2.0  50.359712
# 2     3.0  60.305344
# 3     4.0  47.014925
# 4     5.0  53.389831
# 5     6.0  42.105263
# 6     7.0  57.142857
# 7     8.0  38.666667
# 8     9.0  42.857143
# 9    10.0  26.086957
# 10   11.0  54.838710
# 11   12.0  35.714286
# 12   13.0  56.250000
